# %%
import numpy as np
import pandas as pd
import nltk
import nltk.corpus
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer


import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    id                                              title              author  \
# 0   0  House Dem Aide: We Didn’t Even See Comey’s Let...       Darrell Lucus
# 1   1  FLYNN: Hillary Clinton, Big Woman on Campus - ...     Daniel J. Flynn
# 2   2                  Why the Truth Might Get You Fired  Consortiumnews.com
# 3   3  15 Civilians Killed In Single US Airstrike Hav...     Jessica Purkiss
# 4   4  Iranian woman jailed for fictional unpublished...      Howard Portnoy
#
#                                                 text  label
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 1  Ever get the feeling your life circles the rou...      0
# 2  Why the Truth Might Get You Fired October 29, ...      1
# 3  Videos 15 Civilians Killed In Single US Airstr...      1
# 4  Print \nAn Iranian woman has been sentenced to...      1

# %%
df.shape
# Out:
# (20800, 5)

# %%
df.isnull().sum()
# Out:
# id           0
# title      558
# author    1957
# text        39
# label        0
# dtype: int64

# %% [markdown]
# I didn't want to delete any of the data using dropna, rather I preferred to replace null values with the modes of each field having null values.

# %%
df['title']=df['title'].fillna(df['title'].mode()[0])
df['author']=df['author'].fillna(df['author'].mode()[0])
df['text']=df['text'].fillna(df['text'].mode()[0])

# %%
df['title']=df['title'].str.lower() 
df['author']=df['author'].str.lower()
# This avoids having multiple copies of the same words. For example, 
#'Give' and 'give' will be taken as different words if this code is ignored.

# %%
# Stopwords are the English words which does not add much meaning to a sentence. They can safely be 
# ignored without sacrificing the meaning of the sentence. Examples are the, he, have etc. Such words 
# are already captured in corpus (import nltk.corpus). Their exclusion from texts, which results into 
# word reduction, often times increases the accuracy of training model.

nltk.download('stopwords')

stop_words = stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Student\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
print(stop_words)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
from sklearn.feature_extraction import text
stop=text.ENGLISH_STOP_WORDS
print(stop)
# the sklearn stopwords was employed to further reduce the words in the text and thus increase the 
# accuracy of the model. Stopwords in sklearn are different from those from nltk.corpus
# Out:
# frozenset({'each', 'everywhere', 'other', 'above', 'con', 'whither', 'beyond', 'well', 'find', 'still', 'de', 'hundred', 'nothing', 'latterly', 'none', 'whatever', 'too', 'few', 'where', 'ours', 'describe', 'everyone', 'six', 'yet', 'since', 'anyone', 'could', 'moreover', 'throughout', 'ten', 'former', 'whom', 'twenty', 'towards', 'would', 'amongst', 'us', 'about', 'nowhere', 'might', 'you', 'of', 'these', 'third', 'there', 'were', 'itself', 'detail', 'ever', 'his', 'anyhow', 'sincere', 'those', 'ltd', 'cannot', 'themselves', 'the', 'couldnt', 'mine', 'up', 'behind', 'name', 'next', 'some', 'their', 'however', 're', 'somewhere', 'this', 'will', 'am', 'became', 'being', 'forty', 'serious', 'thereafter', 'herself', 'but', 'anywhere', 'indeed', 'eight', 'four', 'bottom', 'wherein', 'had', 'top', 'bill', 'even', 'toward', 'to', 'therein', 'seems', 'him', 'whenever', 'thick', 'etc', 'back', 'that', 'un', 'fire', 'with', 'during', 'besides', 'out', 'all', 'afterwards', 'another', 'if', 'front', 'latter', 'it', 'among', 'thus', 'last', 'own', 'put', 'thin', 'interest', 'before', 'sometime', 'somehow', 'as', 'except', 'been', 'beside', 'inc', 'down', 'nevertheless', 'most', 'made', 'meanwhile', 'amount', 'in', 'done', 'he', 'while', 'cant', 'which', 'thru', 'they', 'at', 'although', 'an', 'go', 'without', 'yours', 'whereby', 'move', 'namely', 'hereby', 'can', 'on', 'almost', 'fifteen', 'either', 'thence', 'someone', 'from', 'becoming', 'such', 'otherwise', 'by', 'and', 'several', 'show', 'across', 'must', 'nor', 'below', 'onto', 'myself', 'me', 'once', 'herein', 'found', 'has', 'three', 'further', 'through', 'sometimes', 'or', 'see', 'between', 'side', 'mill', 'part', 'enough', 'two', 'seemed', 'whereas', 'co', 'its', 'along', 'least', 'them', 'others', 'my', 'nobody', 'same', 'after', 'via', 'is', 'have', 'five', 'beforehand', 'ie', 'for', 'off', 'should', 'thereupon', 'always', 'hereupon', 'eleven', 'whence', 'nine', 'over', 'elsewhere', 'around', 'only', 'empty', 'first', 'wherever', 'together', 'because', 'hasnt', 'noone', 'everything', 'who', 'cry', 'whole', 'whether', 'get', 'please', 'often', 'anyway', 'when', 'she', 'already', 'be', 'here', 'eg', 'system', 'many', 'we', 'one', 'else', 'sixty', 'rather', 'within', 'perhaps', 'yourself', 'much', 'neither', 'per', 'than', 'into', 'hereafter', 'under', 'against', 'become', 'mostly', 'a', 'more', 'therefore', 'anything', 'due', 'very', 'amoungst', 'yourselves', 'not', 'thereby', 'formerly', 'take', 'call', 'both', 'now', 'alone', 'so', 'whereafter', 'something', 'then', 'never', 'though', 'fifty', 'seeming', 'whose', 'keep', 'are', 'i', 'give', 'your', 'was', 'also', 'whoever', 'may', 'again', 'full', 'seem', 'less', 'until', 'becomes', 'do', 'any', 'why', 'how', 'our', 'ourselves', 'every', 'fill', 'her', 'hence', 'hers', 'upon', 'what', 'whereupon', 'himself', 'no', 'twelve'})

# %%
df['revtitle'] = df['title'].astype(str)# this code was considered as a result of an attribute error
#from python stating title column is not string
df['clean_title'] = df['revtitle'].apply(lambda x: ' '.join([word for word in x.split() if word not 
                                                             in (stop_words) and (stop)]))
#using the lambda x and split functions in python

# %%
df['rev'] = df['author'].astype(str)# same as above
df['clean_author'] = df['rev'].apply(lambda x: ' '.join([word for word in x.split() if word not in 
                                                         (stop_words) and (stop)]))

# %%
df['content']=df['clean_title']+' '+df['clean_author']
df['content'] #concertenating both clean_title and clean_author
# Out:
# 0        house dem aide: didn’t even see comey’s letter...
# 1        flynn: hillary clinton, big woman campus - bre...
# 2                 truth might get fired consortiumnews.com
# 3        15 civilians killed single us airstrike identi...
# 4        iranian woman jailed fictional unpublished sto...
#                                ...
# 20795    rapper t.i.: trump ’poster child white suprema...
# 20796    n.f.l. playoffs: schedule, matchups odds - new...
# 20797    macy’s said receive takeover approach hudson’s...
# 20798    nato, russia hold parallel exercises balkans a...
# 20799                       keeps f-35 alive david swanson
# Name: content, Length: 20800, dtype: object

# %%
print(list(df))
# Out:
# ['id', 'title', 'author', 'text', 'label', 'revtitle', 'clean_title', 'rev', 'clean_author', 'content']

# %%
df.head()
# Out:
#    id                                              title              author  \
# 0   0  house dem aide: we didn’t even see comey’s let...       darrell lucus
# 1   1  flynn: hillary clinton, big woman on campus - ...     daniel j. flynn
# 2   2                  why the truth might get you fired  consortiumnews.com
# 3   3  15 civilians killed in single us airstrike hav...     jessica purkiss
# 4   4  iranian woman jailed for fictional unpublished...      howard portnoy
#
#                                                 text  label  \
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 1  Ever get the feeling your life circles the rou...      0
# 2  Why the Truth Might Get You Fired October 29, ...      1
# 3  Videos 15 Civilians Killed In Single US Airstr...      1
# 4  Print \nAn Iranian woman has been sentenced to...      1
#
#                                             revtitle  \
# 0  house dem aide: we didn’t even see comey’s let...
# 1  flynn: hillary clinton, big woman on campus - ...
# 2                  why the truth might get you fired
# 3  15 civilians killed in single us airstrike hav...
# 4  iranian woman jailed for fictional unpublished...
#
#                                          clean_title                 rev  \
# 0  house dem aide: didn’t even see comey’s letter...       darrell lucus
# 1  flynn: hillary clinton, big woman campus - bre...     daniel j. flynn
# 2                              truth might get fired  consortiumnews.com
# 3  15 civilians killed single us airstrike identi...     jessica purkiss
# 4  iranian woman jailed fictional unpublished sto...      howard portnoy
#
#          clean_author                                            content
# 0       darrell lucus  house dem aide: didn’t even see comey’s letter...
# 1     daniel j. flynn  flynn: hillary clinton, big woman campus - bre...
# 2  consortiumnews.com           truth might get fired consortiumnews.com
# 3     jessica purkiss  15 civilians killed single us airstrike identi...
# 4      howard portnoy  iranian woman jailed fictional unpublished sto...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20800 entries, 0 to 20799
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            20800 non-null  int64
#  1   title         20800 non-null  object
#  2   author        20800 non-null  object
#  3   text          20800 non-null  object
#  4   label         20800 non-null  int64
#  5   revtitle      20800 non-null  object
#  6   clean_title   20800 non-null  object
#  7   rev           20800 non-null  object
#  8   clean_author  20800 non-null  object
#  9   content       20800 non-null  object
# dtypes: int64(2), object(8)
# memory usage: 1.6+ MB

# %%
df['content'][0]
# Out:
# 'house dem aide: didn’t even see comey’s letter jason chaffetz tweeted darrell lucus'

# %%
ps=PorterStemmer()
#stemming the content column of interest. Stemming is targeted towards replacing similar words with 
#their root word e.g actress, acted, acting, action....all have a root word called act. Stemming also 
#reduces the length of words

# %%
new_content=[]#declaring the stemmed text as a list stored in a variable called new_content
for w in df.content[:]:
    new_content.append(ps.stem(w))
print(new_content)
# Out:
# ['house dem aide: didn’t even see comey’s letter jason chaffetz tweeted darrell lucu', 'flynn: hillary clinton, big woman campus - breitbart daniel j. flynn', 'truth might get fired consortiumnews.com', '15 civilians killed single us airstrike identified jessica purkiss', 'iranian woman jailed fictional unpublished story woman stoned death adultery howard portnoy', 'jackie mason: hollywood would love trump bombed north korea lack trans bathrooms (exclusive video) - breitbart daniel nussbaum', 'life: life luxury: elton john’s 6 favorite shark pictures stare long, transcontinental flights pam key', 'benoît hamon wins french socialist party’s presidential nomination - new york times alissa j. rubin', 'excerpts draft script donald trump’s q&ampa black church’s pastor - new york times pam key', 'back-channel plan ukraine russia, courtesy trump associates - new york times megan twohey scott shan', 'obama’s organizing action partners soros-linked ‘indivisible’ disrupt trump’s agenda aaron klein', 'bbc comedy sketch "real housewives isis" causes outrage chris tomlinson', 'russian researchers discover secret nazi military base ‘treasure hunter’ arctic [photos] amando flavio', 'us officials see link trump russia jason ditz', 're: yes, paid government trolls social media, blogs, forums websites anotheranni', 'major league soccer, argentines find home success - new york times jack william', 'wells fargo chief abruptly steps - new york times michael corkery stacy cowley', 'anonymous donor pays $2.5 million release everyone arrested dakota access pipeline starkman', 'fbi closes hillary! doc', 'chuck todd: ’buzzfeed donald trump political favor’ - breitbart jeff poor', 'news: hope gop: nude paul ryan emerged ayahuasca tent visions new republican party pam key', 'monica lewinsky, clinton sex scandal set ’american crime story’ jerome hudson', 'rob reiner: trump ’mentally unstable’ - breitbart pam key', 'massachusetts cop’s wife busted pinning fake home-invasion robbery black lives matter pam key', 'abortion pill orders rise 7 latin american nations zika alert - new york times donald g. mcneil jr. pam belluck', 'nukes un: historic treaty ban nuclear weapons ira helfand', 'exclusive: islamic state supporters vow ‘shake’ west following manchester terrorist massacre - breitbart aaron klein ali wak', 'humiliated hillary tries hide camera caught 15 mins rally amanda shea', 'andrea tantaros fox news claims retaliation sex harassment complaints - new york times jim dwy', 'hillary clinton became hawk - new york times mark landl', 'chuck todd buzzfeed eic: ’you published fake news’ - breitbart ian hanchett', 'israel becoming pivotal china’s mid-eastern calculus http://journal-neo.org/2016/11/07/israel-is-becoming-pivotal-to-china-s-mid-eastern-calculus/ pam key', 'won, boris johnson ‘brexit’ leaders fumble - new york times steven erlang', 'texas oil fields rebound price lull, jobs left behind - new york times clifford krauss', 'bayer deal monsanto follows agribusiness trend, raising worries farmers - new york times leslie picker, danny hakim michael j. de la merc', 'russia moves ban jehovah’s witnesses ‘extremist’ - new york times andrew higgin', 're: still ‘the danger zone’ january 20th, 2017 greanfinisher .', 'open thread (not u.s. election) 2016-39 b', 'democrat gutierrez blames chicago’s gun violence nra - breitbart awr hawkin', 'avoiding peanuts avoid allergy bad strategy - new york times aaron e. carrol', 'mri shows detailed images 20-week unborn babies - breitbart dr. susan berri', '4 best kinds milk aren’t dairy alexandria laredo', 'ryan lochte dropped speedo usa retailers - new york times katie rog', 'one girlfriend without bastards f**king up? asks harry pam key', 'conservatives urge sessions clean obama’s civil rights division - breitbart ian mason', 'internal inquiry sealed fate roger ailes fox - new york times jim rutenberg, ben protess emily steel', 'press tv debate: duff lebanon, hezbollah aoun’s presidency (3 videos) gordon duff, senior  ...

# %%
df['stemmed_stopwords_removed']=new_content
df.head()
# Out:
#    id                                              title              author  \
# 0   0  house dem aide: we didn’t even see comey’s let...       darrell lucus
# 1   1  flynn: hillary clinton, big woman on campus - ...     daniel j. flynn
# 2   2                  why the truth might get you fired  consortiumnews.com
# 3   3  15 civilians killed in single us airstrike hav...     jessica purkiss
# 4   4  iranian woman jailed for fictional unpublished...      howard portnoy
#
#                                                 text  label  \
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 1  Ever get the feeling your life circles the rou...      0
# 2  Why the Truth Might Get You Fired October 29, ...      1
# 3  Videos 15 Civilians Killed In Single US Airstr...      1
# 4  Print \nAn Iranian woman has been sentenced to...      1
#
#                                             revtitle  \
# 0  house dem aide: we didn’t even see comey’s let...
# 1  flynn: hillary clinton, big woman on campus - ...
# 2                  why the truth might get you fired
# 3  15 civilians killed in single us airstrike hav...
# 4  iranian woman jailed for fictional unpublished...
#
#                                          clean_title                 rev  \
# 0  house dem aide: didn’t even see comey’s letter...       darrell lucus
# 1  flynn: hillary clinton, big woman campus - bre...     daniel j. flynn
# 2                              truth might get fired  consortiumnews.com
# 3  15 civilians killed single us airstrike identi...     jessica purkiss
# 4  iranian woman jailed fictional unpublished sto...      howard portnoy
#
#          clean_author                                            content  \
# 0       darrell lucus  house dem aide: didn’t even see comey’s letter...
# 1     daniel j. flynn  flynn: hillary clinton, big woman campus - bre...
# 2  consortiumnews.com           truth might get fired consortiumnews.com
# 3     jessica purkiss  15 civilians killed single us airstrike identi...
# 4      howard portnoy  iranian woman jailed fictional unpublished sto...
#
#                            stemmed_stopwords_removed
# 0  house dem aide: didn’t even see comey’s letter...
# 1  flynn: hillary clinton, big woman campus - bre...
# 2           truth might get fired consortiumnews.com
# 3  15 civilians killed single us airstrike identi...
# 4  iranian woman jailed fictional unpublished sto...

# %%
print(type(df.stemmed_stopwords_removed))
# Out:
# <class 'pandas.core.series.Series'>

# %%
df['stemmed_stopwords_removed']
# Out:
# 0        house dem aide: didn’t even see comey’s letter...
# 1        flynn: hillary clinton, big woman campus - bre...
# 2                 truth might get fired consortiumnews.com
# 3        15 civilians killed single us airstrike identi...
# 4        iranian woman jailed fictional unpublished sto...
#                                ...
# 20795    rapper t.i.: trump ’poster child white suprema...
# 20796    n.f.l. playoffs: schedule, matchups odds - new...
# 20797    macy’s said receive takeover approach hudson’s...
# 20798    nato, russia hold parallel exercises balkans a...
# 20799                       keeps f-35 alive david swanson
# Name: stemmed_stopwords_removed, Length: 20800, dtype: object

# %%
X=df['stemmed_stopwords_removed']
Y=df.label

# %%
#converting textual documents to numerical values
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
clf=Pipeline([
    ('vectorizer',CountVectorizer()),
    ('lr',LogisticRegression())
    
])
#vectorizer=TfidfVectorizer()

# %%
# vectorizer.fit(X)

# %%
# X=vectorizer.transform(X)

# %%
# X.shape

# %%
# Y.shape

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42,stratify=Y)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
X_train
# Out:
# 18697    thousands mourners celebrate gwen ifill’s tena...
# 19320    oklahoma governor vetoes bill would charge abo...
# 13879          fascism india - countercurrents.org pam key
# 15282    ‘terrifying’: at&t spying americans profit, ne...
# 17746    new project veritas release: rigging election ...
#                                ...
# 13180    poll: corrupt federal agency? anonymous coward...
# 11811    hillary campaign hates pander “f*cking dumb” m...
# 17375    gene tests identify breast cancer patients ski...
# 20189    france: police siege muslim migrant areas arou...
# 3515     donald trump & hillary clinton ~ rap song (the...
# Name: stemmed_stopwords_removed, Length: 16640, dtype: object

# %%
X_train.shape
# Out:
# (16640,)

# %%
Y_train
# Out:
# 18697    0
# 19320    0
# 13879    1
# 15282    1
# 17746    1
#         ..
# 13180    1
# 11811    1
# 17375    0
# 20189    1
# 3515     1
# Name: label, Length: 16640, dtype: int64

# %%
clf.fit(X_train,Y_train)
# Out:
# Pipeline(steps=[('vectorizer', CountVectorizer()),
#                 ('lr', LogisticRegression())])

# %%
y_predicted=clf.predict(X_test)
y_predicted
# Out:
# array([0, 0, 1, ..., 0, 1, 0], dtype=int64)

# %%
from sklearn import metrics
metrics.accuracy_score(Y_test,y_predicted)
# Out:
# 0.9872596153846154

# %%
metrics.f1_score(Y_test,y_predicted)
# Out:
# 0.987377947130269

# %%
clf.score(X_test,Y_test)
# Out:
# 0.9872596153846154

# %%
clf.score(X_train,Y_train)
# Out:
# 0.99921875

# %% [markdown]
# ### pre-processing of the test file for prediction

# %%
submit=pd.read_csv('submit.csv')
test=pd.read_csv('test.csv')

# %%
submit.head()
# Out:
#       id  label
# 0  20800      0
# 1  20801      1
# 2  20802      0
# 3  20803      1
# 4  20804      1

# %%
test.head()
# Out:
#       id                                              title  \
# 0  20800  Specter of Trump Loosens Tongues, if Not Purse...
# 1  20801  Russian warships ready to strike terrorists ne...
# 2  20802  #NoDAPL: Native American Leaders Vow to Stay A...
# 3  20803  Tim Tebow Will Attempt Another Comeback, This ...
# 4  20804                    Keiser Report: Meme Wars (E995)
#
#                     author                                               text
# 0         David Streitfeld  PALO ALTO, Calif.  —   After years of scorning...
# 1                      NaN  Russian warships ready to strike terrorists ne...
# 2            Common Dreams  Videos #NoDAPL: Native American Leaders Vow to...
# 3            Daniel Victor  If at first you don’t succeed, try a different...
# 4  Truth Broadcast Network  42 mins ago 1 Views 0 Comments 0 Likes 'For th...

# %%
test.shape
# Out:
# (5200, 4)

# %%
test.isnull().sum()
# Out:
# id          0
# title     122
# author    503
# text        7
# dtype: int64

# %%
test['title']=test['title'].fillna(test['title'].mode()[0])
test['author']=test['author'].fillna(test['author'].mode()[0])
test['text']=test['text'].fillna(test['text'].mode()[0])

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5200 entries, 0 to 5199
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      5200 non-null   int64
#  1   title   5200 non-null   object
#  2   author  5200 non-null   object
#  3   text    5200 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 162.6+ KB

# %%
test['revtitle'] = test['title'].astype(str)
test['clean_title'] = test['revtitle'].apply(lambda x: ' '.join([word for word in x.split() if word not 
                                                             in (stop_words) and (stop)]))

# %%
test['rev'] = test['author'].astype(str)
test['clean_author'] = test['rev'].apply(lambda x: ' '.join([word for word in x.split() if word not in 
                                                         (stop_words) and (stop)]))

# %%
test['content']=test['clean_title']+' '+test['clean_author']
test['content']
# Out:
# 0       Specter Trump Loosens Tongues, Not Purse Strin...
# 1       Russian warships ready strike terrorists near ...
# 2       #NoDAPL: Native American Leaders Vow Stay All ...
# 3       Tim Tebow Will Attempt Another Comeback, This ...
# 4       Keiser Report: Meme Wars (E995) Truth Broadcas...
#                               ...
# 5195    The Bangladeshi Traffic Jam That Never Ends - ...
# 5196    John Kasich Signs One Abortion Bill Ohio Vetoe...
# 5197    California Today: What, Exactly, Is Your Sushi...
# 5198    300 US Marines To Be Deployed To Russian Borde...
# 5199    Awkward Sex, Onscreen Off - The New York Times...
# Name: content, Length: 5200, dtype: object

# %%
stemmed_test=[]
for w in test.content[:]:
    stemmed_test.append(ps.stem(w))
print(stemmed_test)
# Out:
# ['specter trump loosens tongues, not purse strings, silicon valley - the new york times david streitfeld', 'russian warships ready strike terrorists near aleppo pam key', '#nodapl: native american leaders vow stay all winter, file lawsuit against police common dream', 'tim tebow will attempt another comeback, this time baseball - the new york times daniel victor', 'keiser report: meme wars (e995) truth broadcast network', "trump usa's antique hero. clinton next president pam key", 'pelosi calls fbi investigation find out ’what russians have donald trump’ - breitbart pam key', 'weekly featured profile – randy shannon trevor loudon', 'urban population booms will make climate change worse pam key', 'are the polls rigged against trump? all of these wildly divergent surveys cannot possibly be correct cognitive dissid', '184 u.s. generals admirals endorse trump commander-in-chief dr. eowyn', '“working class hero” john brennon doug diamond', 'the rise mandatory vaccinations means end medical freedom shaun bradley', 'communists terrorize small business steve watson', 'computer programmer comes forward, admits to being paid to rig voting booths! trump was right! • usa newsflash usa news flash', 'thieves take chunk change, all 221 pounds it, from berlin museum - the new york times melissa eddi', 'new england patriots’ owner, still sore n.f.l., has payback sight - the new york times ken belson ben shpigel', 'college republicans, yaf sue berkeley ann coulter event - breitbart tom ciccotta', 'trump melts down and accuses the us postal service of stealing the election for clinton jason easley', 'visiting madagascar? leave red swimsuits (and lemur recipes) home - the new york times bryant rousseau', 'reese’s peanut butter cups – cheap full toxic chemicals reald', 'president obama president-elect donald trump meet white house reald', 'are the polls rigged against trump? all of these wildly divergent surveys cannot possibly be correct dale johnson', 'the real numbers florida: trump winning 14 points andrew anglin', 'ann coulter on c-span quotes vdare.com’s brimelow–a racist is someone winning an argument with a liberal. james fulford', '‘age empires’: how 2 dynasties art forged china’s identity - the new york times holland cott', 'because stupid! naral created deck ‘gender cards’ hillary; guess card sam j.', 'bill weld, running libertarian, likens donald trump’s immigration plan kristallnacht - the new york times maggie haberman thomas kaplan', 'how housing’s new players spiraled into banks’ old mistakes - the new york times matthew goldstein, rachel abrams ben protess', 'переплюнуть калигулу… жанна ивченко', 'sen booker: trump is creating ’toxic’ environment ’fear’ - breitbart pam key', 'facebook wall: reactions donald trump’s victory us presidential elections unreal mama', 'in ‘divorce,’ sarah jessica parker wants ditch mr. medium - the new york times james poniewozik', 'senate passes bill exposing saudi arabia 9/11 legal claims - the new york times mark mazzetti', 'dapl protesters proven right largest gas pipeline u.s. experiences massive deadly explosion – anonymous pam key', 'bhumibol adulyadej, 88, people’s king thailand, dies after 7-decade reign - the new york times barbara crossett', 'krauthammer: gorsuch filibuster ’totally illogical’ move fueled ’trump derangement syndrome’ - breitbart ian hanchett', 'stop trump mixtape: a protest song collection kevin gosztola', 'what happened fbi? andrew napolitano', 'clubbers lament demise fabric, ‘totem’ london’s dance scene - the new york times dan bilefski', 'a hushed departure met museum reveals entrenched management culture - the new york times robin pogrebin', 'trump: confidence in economy ’has reached levels not seen in many, many years’ - breitbart ian hanchett', 'are the polls rigged against trump? all of these wildly divergent surveys cannot possibly be correct doctor who?', 'jason miller backs out white house communications job under trump - the new york times michael d. shear', 'turki ...

# %%
test['test_stemmed_stopwords_removed']=stemmed_test
test.head()
# Out:
#       id                                              title  \
# 0  20800  Specter of Trump Loosens Tongues, if Not Purse...
# 1  20801  Russian warships ready to strike terrorists ne...
# 2  20802  #NoDAPL: Native American Leaders Vow to Stay A...
# 3  20803  Tim Tebow Will Attempt Another Comeback, This ...
# 4  20804                    Keiser Report: Meme Wars (E995)
#
#                     author                                               text  \
# 0         David Streitfeld  PALO ALTO, Calif.  —   After years of scorning...
# 1                  Pam Key  Russian warships ready to strike terrorists ne...
# 2            Common Dreams  Videos #NoDAPL: Native American Leaders Vow to...
# 3            Daniel Victor  If at first you don’t succeed, try a different...
# 4  Truth Broadcast Network  42 mins ago 1 Views 0 Comments 0 Likes 'For th...
#
#                                             revtitle  \
# 0  Specter of Trump Loosens Tongues, if Not Purse...
# 1  Russian warships ready to strike terrorists ne...
# 2  #NoDAPL: Native American Leaders Vow to Stay A...
# 3  Tim Tebow Will Attempt Another Comeback, This ...
# 4                    Keiser Report: Meme Wars (E995)
#
#                                          clean_title                      rev  \
# 0  Specter Trump Loosens Tongues, Not Purse Strin...         David Streitfeld
# 1  Russian warships ready strike terrorists near ...                  Pam Key
# 2  #NoDAPL: Native American Leaders Vow Stay All ...            Common Dreams
# 3  Tim Tebow Will Attempt Another Comeback, This ...            Daniel Victor
# 4                    Keiser Report: Meme Wars (E995)  Truth Broadcast Network
#
#               clean_author                                            content  \
# 0         David Streitfeld  Specter Trump Loosens Tongues, Not Purse Strin...
# 1                  Pam Key  Russian warships ready strike terrorists near ...
# 2            Common Dreams  #NoDAPL: Native American Leaders Vow Stay All ...
# 3            Daniel Victor  Tim Tebow Will Attempt Another Comeback, This ...
# 4  Truth Broadcast Network  Keiser Report: Meme Wars (E995) Truth Broadcas...
#
#                       test_stemmed_stopwords_removed
# 0  specter trump loosens tongues, not purse strin...
# 1  russian warships ready strike terrorists near ...
# 2  #nodapl: native american leaders vow stay all ...
# 3  tim tebow will attempt another comeback, this ...
# 4  keiser report: meme wars (e995) truth broadcas...

# %%
test['label']=submit.label
test.head()
# Out:
#       id                                              title  \
# 0  20800  Specter of Trump Loosens Tongues, if Not Purse...
# 1  20801  Russian warships ready to strike terrorists ne...
# 2  20802  #NoDAPL: Native American Leaders Vow to Stay A...
# 3  20803  Tim Tebow Will Attempt Another Comeback, This ...
# 4  20804                    Keiser Report: Meme Wars (E995)
#
#                     author                                               text  \
# 0         David Streitfeld  PALO ALTO, Calif.  —   After years of scorning...
# 1                  Pam Key  Russian warships ready to strike terrorists ne...
# 2            Common Dreams  Videos #NoDAPL: Native American Leaders Vow to...
# 3            Daniel Victor  If at first you don’t succeed, try a different...
# 4  Truth Broadcast Network  42 mins ago 1 Views 0 Comments 0 Likes 'For th...
#
#                                             revtitle  \
# 0  Specter of Trump Loosens Tongues, if Not Purse...
# 1  Russian warships ready to strike terrorists ne...
# 2  #NoDAPL: Native American Leaders Vow to Stay A...
# 3  Tim Tebow Will Attempt Another Comeback, This ...
# 4                    Keiser Report: Meme Wars (E995)
#
#                                          clean_title                      rev  \
# 0  Specter Trump Loosens Tongues, Not Purse Strin...         David Streitfeld
# 1  Russian warships ready strike terrorists near ...                  Pam Key
# 2  #NoDAPL: Native American Leaders Vow Stay All ...            Common Dreams
# 3  Tim Tebow Will Attempt Another Comeback, This ...            Daniel Victor
# 4                    Keiser Report: Meme Wars (E995)  Truth Broadcast Network
#
#               clean_author                                            content  \
# 0         David Streitfeld  Specter Trump Loosens Tongues, Not Purse Strin...
# 1                  Pam Key  Russian warships ready strike terrorists near ...
# 2            Common Dreams  #NoDAPL: Native American Leaders Vow Stay All ...
# 3            Daniel Victor  Tim Tebow Will Attempt Another Comeback, This ...
# 4  Truth Broadcast Network  Keiser Report: Meme Wars (E995) Truth Broadcas...
#
#                       test_stemmed_stopwords_removed  label
# 0  specter trump loosens tongues, not purse strin...      0
# 1  russian warships ready strike terrorists near ...      1
# 2  #nodapl: native american leaders vow stay all ...      0
# 3  tim tebow will attempt another comeback, this ...      1
# 4  keiser report: meme wars (e995) truth broadcas...      1

# %%
test.isnull().sum()
# Out:
# id                                0
# title                             0
# author                            0
# text                              0
# revtitle                          0
# clean_title                       0
# rev                               0
# clean_author                      0
# content                           0
# test_stemmed_stopwords_removed    0
# label                             0
# dtype: int64

# %%
Z=test['test_stemmed_stopwords_removed']
T=test.label

# %%
# vectorizer.fit(Z)

# %%
# Z=vectorizer.transform(Z)

# %%
clf.fit(Z,T)
# Out:
# Pipeline(steps=[('vectorizer', CountVectorizer()),
#                 ('lr', LogisticRegression())])

# %%
# new_=clf.predict(test.test_stemmed_stopwords_removed)
# newl=pd.DataFrame(new_,columns=['prediction_'])
# newl

# %%
prediction=clf.predict(Z)
submit_mine=pd.DataFrame(prediction,columns=['prediction_submit'])

submit_mine
# Out:
#       prediction_submit
# 0                     0
# 1                     1
# 2                     0
# 3                     1
# 4                     1
# ...                 ...
# 5195                  0
# 5196                  1
# 5197                  0
# 5198                  1
# 5199                  0
#
# [5200 rows x 1 columns]

# %%
prediction[0]
# Out:
# 0

# %%
if prediction[0]==0:
    print ('The article is not fake')
else:
    print('The article is fake')
# Out:
# The article is not fake

# %%
submit_mine.to_csv('submit_liz.csv')

# %%
#for quick comparison between the submit.label given in the dataset and the one predicted 
#(prediction_submit) by the model
new_df=submit_mine
new_df['submit.label']=submit.label
new_df.head()
# Out:
#    prediction_submit  submit.label
# 0                  0             0
# 1                  1             1
# 2                  0             0
# 3                  1             1
# 4                  1             1

# %%
new_df.tail()
# Out:
#       prediction_submit  submit.label
# 5195                  0             0
# 5196                  1             1
# 5197                  0             0
# 5198                  1             1
# 5199                  0             0

# %% [markdown]
# ### Correct prediction above
